# %%
# **Unit Test** - *Deliverable 2[A]*
"In this section, we look at the population of the world, Japan, Niger, and a control country to validate our results of the population statistics"
# Out:
# 'In this section, we look at the population of the world, Japan, Niger, and a control country to validate our results of the population statistics'

# %%
def population_testing ():
    # Look at if the population of the world is correct

    assert population (year=2000, sex='Female', age=0,100), loc='WLD')>0, "too few females" # checks if female pop above 0 
    assert population (year=2000, sex='Male', age=(0,100), loc='WLD') < 7e9 , "number of males incorrect"# checks if male pop lower than world pop

    # Look at whether the population of Japan is correct 

    assert population (year=2000, sex='all', age=(0,100), loc='JPN')>1e7, "population too low"# checks if population in japan is greater than 10M 
    assert population (year=2000, sex='Male', age=(80,100), loc='JPN') < 3e6, "population too high" # checks if japan elderly male population is less than 3M 

    # Look at whether the population of Niger is correct

    assert population (year=2000, sex='all', age=(0,100), loc='NGR')>1e7, "population too low" # checks if population in niger is greater than 10M   
    assert population (year=2000, sex='all', age=(0,20), loc='NGR') < 2e6, "population too high" # checks if youth population in niger is greater than 2M

    # Look at an additional country for reference 
    assert population(year=1966, sex='Female', age=(0, 100), loc='Australia') < 6e6, "population too high" # Checks if population fo australia is higher than 6M

    print ("unit tests passed")

population_testing()
