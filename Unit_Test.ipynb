# %%
Def population_testing ():
    # Look at if the population of the world is correct
    Assert population (year=2000, sex='Female', age=0,100), loc='WLD')>0 # checks if female pop above 0 
    Assert population (year=2000, sex='Male', age=(0,100), loc='WLD') < 7e9 # checks if male pop lower than world pop

    # Look at whether the population of Japan is correct 
    Assert population (year=2000, sex='all', age=(0,100), loc='JPN')>1e7 # checks if population in japan is greater than 10M 
    Assert population (year=2000, sex='Male', age=(80,100), loc='JPN') < 3e6 # checks if elderly population is less than 3M 
    # Look at whether the population of (African country) is correct
    
    # Look at an additional country for reference
