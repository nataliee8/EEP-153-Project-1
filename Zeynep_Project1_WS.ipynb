# %%
# !pip install plotly
# !pip install wbdata
# !pip install cufflinks
import wbdata
import pandas as pd
import numpy as np
from scipy.optimize import newton
# Out:
# Requirement already satisfied: plotly in /srv/conda/lib/python3.11/site-packages (6.3.1)
# Requirement already satisfied: narwhals>=1.15.1 in /srv/conda/lib/python3.11/site-packages (from plotly) (2.10.0)
# Requirement already satisfied: packaging in /srv/conda/lib/python3.11/site-packages (from plotly) (24.2)
# Requirement already satisfied: wbdata in /srv/conda/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: appdirs<2,>=1.4 in /srv/conda/lib/python3.11/site-packages (from wbdata) (1.4.4)
# Requirement already satisfied: backoff<3,>=2.2.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.2.1)
# Requirement already satisfied: cachetools<6,>=5.3.2 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.5.2)
# Requirement already satisfied: dateparser<2,>=1.2.0 in /srv/conda/lib/python3.11/site-packages (from wbdata) (1.3.0)
# Requirement already satisfied: decorator<6,>=5.1.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: requests<3,>=2.0 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.32.3)
# Requirement already satisfied: shelved-cache<0.4,>=0.3.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (0.3.1)
# Requirement already satisfied: tabulate<1,>=0.8.5 in /srv/conda/lib/python3.11/site-packages (from wbdata) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.10.23)
# Requirement already satisfied: tzlocal>=0.2 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (5.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.7.0->dateparser<2,>=1.2.0->wbdata) (1.17.0)
# Requirement already satisfied: cufflinks in /srv/conda/lib/python3.11/site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in /srv/conda/lib/python3.11/site-packages (from cufflinks) (2.2.6)
# Requirement already satisfied: pandas>=0.19.2 in /srv/conda/lib/python3.11/site-packages (from cufflinks) (2.2.3)
# Requirement already satisfied: plotly>=4.1.1 in /srv/conda/lib/python3.11/site-packages (from cufflinks) (6.3.1)
# Requirement already satisfied: six>=1.9.0 in /srv/conda/lib/python3.11/site-packages (from cufflinks) (1.17.0)
# Requirement already satisfied: colorlover>=0.2.1 in /srv/conda/lib/python3.11/site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in /srv/conda/lib/python3.11/site-packages (from cufflinks) (75.6.0)
# Requirement already satisfied: ipython>=5.3.0 in /srv/conda/lib/python3.11/site-packages (from cufflinks) (9.6.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /srv/conda/lib/python3.11/site-packages (from cufflinks) (8.1.5)
# Requirement already satisfied: decorator in /srv/conda/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: ipython-pygments-lexers in /srv/conda/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /srv/conda/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /srv/conda/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /srv/conda/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /srv/conda/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /srv/conda/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (2.19.2)
# Requirement already satisfied: stack_data in /srv/conda/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /srv/conda/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in /srv/conda/lib/python3.11/site-packages (from ipython>=5.3.0->cufflinks) (4.12.2)
# Requirement already satisfied: wcwidth in /srv/conda/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.2.14)
# Requirement already satisfied: comm>=0.1.3 in /srv/conda/lib/python3.11/site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /srv/conda/lib/python3.11/site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.12 in /srv/conda/lib/python3.11/site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.15)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /srv/conda/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/lib/python3.11/site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.11/site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/lib/python3.11/site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /srv/conda/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.3.0->cufflinks) (0.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in /srv/conda/lib/python3.11/site-packages (from plotly>=4.1.1->cufflinks) (2.10.0)
# Requirement already satisfied: packaging in /srv/conda/lib/python3.11/site-packages (from plotly>=4.1.1->cufflinks) (24.2)
# Requirement already satisfied: executing>=1.2.0 in /srv/conda/lib/python3.11/site-packages (from stack_data->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /srv/conda/lib/python3.11/site-packages (from stack_data->ipython>=5.3.0->cufflinks) (3.0.0)
# Requirement already satisfied: pure_eval in /srv/conda/lib/python3.11/site-packages (from stack_data->ipython>=5.3.0->cufflinks) (0.2.3)
# Key '-7578703893284724682' not in persistent cache.
# Key '84485591698201752' not in persistent cache.
# Key '2895488979215487719' not in persistent cache.
# Key '8715403034753921386' not in persistent cache.
# Key '-4557832070393809151' not in persistent cache.
# Key '790085877682580702' not in persistent cache.
# Key '7867721569267061978' not in persistent cache.
# Key '-7768019116925203671' not in persistent cache.
# Key '6988433700830578119' not in persistent cache.
# Key '7151765182697375389' not in persistent cache.
# Key '5012770520909437388' not in persistent cache.
# Key '-262931279148216788' not in persistent cache.
# Key '-3310733041341447756' not in persistent cache.
# Key '2055352299715713572' not in persistent cache.
# Key '5935416543999780629' not in persistent cache.
# Key '6028250528744870180' not in persistent cache.
# Key '1793224627627299322' not in persistent cache.
# Key '4472502936227412470' not in persistent cache.
# Key '4726740348776738433' not in persistent cache.
# Key '945543162140439914' not in persistent cache.
# Key '8154903932642094009' not in persistent cache.
# Key '-8870283468513392068' not in persistent cache.
# Key '-3696774499951570989' not in persistent cache.
# Key '-5351213953965507799' not in persistent cache.
# Key '-2671935645365394651' not in persistent cache.
# Key '-2508604163498597381' not in persistent cache.
# Key '-6198895419452367207' not in persistent cache.
# Key '1010465351049286888' not in persistent cache.
# Key '-4536018963361391949' not in persistent cache.
# Key '-2765691474784189300' not in persistent cache.
# Key '5587221548097274523' not in persistent cache.
# Key '-7493437184555115765' not in persistent cache.
# Key '-3613372940271048708' not in persistent cache.
# Key '-3520538955525959157' not in persistent cache.
# Key '-709535568008673190' not in persistent cache.
# Key '-5076286548043416867' not in persistent cache.
# Key '-4822049135494090904' not in persistent cache.
# Key '-1557217033495532598' not in persistent cache.
# Key '-1393885551628735328' not in persistent cache.
# Key '7073700409560187036' not in persistent cache.
# Key '5201180089487151290' not in persistent cache.
# Key '3546740635473214480' not in persistent cache.
# Key '6226018944073327628' not in persistent cache.
# Key '6389350425940124898' not in persistent cache.
# Key '2699059169986355072' not in persistent cache.
# Key '-8538324133221542449' not in persistent cache.
# Key '5361178897202735964' not in persistent cache.
# Key '-6916880304945244875' not in persistent cache.
# Key '1436032717936218948' not in persistent cache.
# Key '2403760676009012148' not in persistent cache.
# Key '-7764561770432104283' not in persistent cache.
# Key '6376658905038168756' not in persistent cache.
# Key '-4860724398169728765' not in persistent cache.
# Key '9219268695505079174' not in persistent cache.
# Key '5075148725070037009' not in persistent cache.
# Key '-5708405863656588173' not in persistent cache.
# Key '-2897402476139302206' not in persistent cache.
# Key '2922511579399131461' not in persistent cache.
# Key '8096020547960952540' not in persistent cache.
# Key '-604448194687841095' not in persistent cache.
# Key '2074830113912272053' not in persistent cache.
# Key '4885833501429558020' not in persistent cache.
# Key '5593899628460156322' not in persistent cache.
# Key '1358873727342585464' not in persistent cache.
# Key '8863422282195156058' not in persistent cache.
# Key '-3414636919952824781' not in persistent cache.
# Key '4938276102928639042' not in persistent cache.
# Key '5906004061001432242' not in persistent cache.
# Key '-4262318385439684189' not in persistent cache.
# Key '-8567841783678962766' not in persistent cache.
# Key '-8404510301812165496' not in persistent cache.
# Key '-5725231993212052348' not in persistent cache.
# Key '8577392110062457103' not in persistent cache.
# Key '-2206162478664168079' not in persistent cache.
# Key '-6441188379781738937' not in persistent cache.
# Key '-621274324243305270' not in persistent cache.
# Key '4552234644318515809' not in persistent cache.
# Key '2897795190304578999' not in persistent cache.
# Key '5577073498904692147' not in persistent cache.
# Key '1342047597787121289' not in persistent cache.
# Key '2050113724817719591' not in persistent cache.
# Key '4861117112335005558' not in persistent cache.
# Key '-7319704456599455315' not in persistent cache.
# Key '-8197048873672741363' not in persistent cache.
# Key '7201893437843579285' not in persistent cache.
# Key '8169621395916372485' not in persistent cache.
# Key '-9044730339159600771' not in persistent cache.
# Key '-6304224448764022523' not in persistent cache.
# Key '-6140892966897225253' not in persistent cache.
# Key '-3461614658297112105' not in persistent cache.
# Key '-7605734628732154270' not in persistent cache.
# Key '-6988574432384084661' not in persistent cache.
# Key '220786338117569434' not in persistent cache.
# Key '1642343010671634973' not in persistent cache.
# Key '6815851979233456052' not in persistent cache.
# Key '5161412525219519242' not in persistent cache.
# Key '794661545184775565' not in persistent cache.
# Key '8004022315686429660' not in persistent cache.
# Key '4313731059732659834' not in persistent cache.
# Key '7124734447249945801' not in persistent cache.
# Key '-6285642917654390382' not in persistent cache.
# Key '7298352502783583478' not in persistent cache.
# Key '-4153193440994971484' not in persistent cache.
# Key '1579985565316142212' not in persistent cache.
# Key '-3695716234741511964' not in persistent cache.
# Key '4657196788139951859' not in persistent cache.
# Key '-1377432655877581604' not in persistent cache.
# Key '-4543397700228371372' not in persistent cache.
# Key '-4450563715483281821' not in persistent cache.
# Key '-1639560327965995854' not in persistent cache.
# Key '-6006311308000739531' not in persistent cache.
# Key '-5752073895451413568' not in persistent cache.
# Key '-2487241793452855262' not in persistent cache.
# Key '4722118977048798833' not in persistent cache.
# Key '6143675649602864372' not in persistent cache.
# Key '-7129559455544866165' not in persistent cache.
# Key '2616715875515891816' not in persistent cache.
# Key '5295994184116004964' not in persistent cache.
# Key '-5941389119091892557' not in persistent cache.
# Key '8815063698663889233' not in persistent cache.
# Key '8978395180530686503' not in persistent cache.
# Key '-6080778225582691474' not in persistent cache.
# Key '-6958122642655977522' not in persistent cache.
# Key '8440819668860343126' not in persistent cache.
# Key '-9038196446776415290' not in persistent cache.
# Key '-759774819507980105' not in persistent cache.
# Key '-5065298217747258682' not in persistent cache.
# Key '-4901966735880461412' not in persistent cache.
# Key '-2222688427280348264' not in persistent cache.
# Key '-6366808397715390429' not in persistent cache.
# Key '1296381087267536005' not in persistent cache.

# %% [markdown]
# # **Population DataFrame** - *Deliverable 3[A]*
# This section contains a function that returns a pandas DataFrame indexed by Country, Year and indicator group (including indicators for different age-sex groups). The function allows for dataframes to be created that include multiple countries, a range of years, and multiple indicator groups. Examples can be found below.

# %%
INDICATOR_GROUPS = {
    #Female Population by 5-year age group
    "pop_female_age":{
        'SP.POP.0004.FE': 'Population ages 0-4, female',
        'SP.POP.0509.FE': 'Population ages 5-9, female',
        'SP.POP.1014.FE': 'Population ages 10-14, female',
        'SP.POP.1519.FE': 'Population ages 15-19, female',
        'SP.POP.2024.FE': 'Population ages 20-24, female',
        'SP.POP.2529.FE': 'Population ages 25-29, female',
        'SP.POP.3034.FE': 'Population ages 30-34, female',
        'SP.POP.3539.FE': 'Population ages 35-39, female',
        'SP.POP.4044.FE': 'Population ages 40-44, female',
        'SP.POP.4549.FE': 'Population ages 45-49, female',
        'SP.POP.5054.FE': 'Population ages 50-54, female',
        'SP.POP.5559.FE': 'Population ages 55-59, female',
        'SP.POP.6064.FE': 'Population ages 60-64, female',
        'SP.POP.6569.FE': 'Population ages 65-69, female',
        'SP.POP.7074.FE': 'Population ages 70-74, female',
        'SP.POP.7579.FE': 'Population ages 75-79, female',
        'SP.POP.80UP.FE': 'Population ages 80 and above, female',
    },
    #Male Population by 5-year age group 
    "pop_male_age":{
        'SP.POP.0004.MA': 'Population ages 0-4, male',
        'SP.POP.0509.MA': 'Population ages 5-9, male',
        'SP.POP.1014.MA': 'Population ages 10-14, male',
        'SP.POP.1519.MA': 'Population ages 15-19, male',
        'SP.POP.2024.MA': 'Population ages 20-24, male',
        'SP.POP.2529.MA': 'Population ages 25-29, male',
        'SP.POP.3034.MA': 'Population ages 30-34, male',
        'SP.POP.3539.MA': 'Population ages 35-39, male',
        'SP.POP.4044.MA': 'Population ages 40-44, male',
        'SP.POP.4549.MA': 'Population ages 45-49, male',
        'SP.POP.5054.MA': 'Population ages 50-54, male',
        'SP.POP.5559.MA': 'Population ages 55-59, male',
        'SP.POP.6064.MA': 'Population ages 60-64, male',
        'SP.POP.6569.MA': 'Population ages 65-69, male',
        'SP.POP.7074.MA': 'Population ages 70-74, male',
        'SP.POP.7579.MA': 'Population ages 75-79, male',
        'SP.POP.80UP.MA': 'Population ages 80 and above, male',
    },
    #Young and Old Populations 
    "young_old_pop":{
        'SP.POP.0014.TO': 'Population ages 0-14, total',
        'SP.POP.0014.MA': 'Population ages 0-14, male',
        'SP.POP.0014.FE': 'Population ages 0-14, female',
        'SP.POP.0014.TO.ZS': 'Population ages 0-14 (% of total)',
        'SP.POP.1564.TO': 'Population ages 15-64, total',
        'SP.POP.1564.MA': 'Population ages 15-64, male',
        'SP.POP.1564.FE': 'Population ages 15-64, female',
        'SP.POP.1564.TO.ZS': 'Population ages 15-64 (% of total)',
        'SP.POP.65UP.TO': 'Population ages 65 and above, total',
        'SP.POP.65UP.MA': 'Population ages 65 and above, male',
        'SP.POP.65UP.FE': 'Population ages 65 and above, female',
        'SP.POP.65UP.TO.ZS': 'Population ages 65 and above (% of total)',
    },
    #Rural and Urban Populations 
    "rural_urban_pop":{
        'SP.RUR.TOTL': 'Rural population',
        'SP.RUR.TOTL.ZS': 'Rural population (% of total)',
        'SP.URB.TOTL': 'Urban population',
        'SP.URB.TOTL.ZS': 'Urban population (% of total)',
        'SP.URB.GROW': 'Urban population growth (annual %)',
    },
    #Population Totals 
    "total_pop":{
        'SP.POP.TOTL': 'Population, total',
        'SP.POP.TOTL.FE.ZS': 'Population, female (% of total)',
        'SP.POP.TOTL.MA.ZS': 'Population, male (% of total)',
        'SP.POP.GROW': 'Population growth (annual %)',
    },   
    #Agricultural Data 
    "agriculture": {
        "AG.LND.AGRI.ZS": "Agricultural land (% of land area)",
        "AG.LND.ARBL.ZS": "Arable land (% of land area)",
        "NV.AGR.TOTL.ZS": "Agriculture, forestry, and fishing, value added (% of GDP)",
        "AG.AGR.EMPL.ZS": "Employment in agriculture (% of total employment)",
        "AG.PRD.CREL.KG": "Cereal yield (kg per hectare)",           
        "AG.PRD.FOOD.XD": "Food production index (2014-2016=100)"
    },
    #GDP Data
    "GDP": {
        "NY.GDP.MKTP.CD": "GDP (current US$)",
        "NY.GDP.MKTP.KD.ZG": "GDP growth (annual %)",
        "NY.GDP.PCAP.CD": "GDP per capita (current US$)",
        "NV.IND.TOTL.ZS": "Industry value added (% of GDP)",
        "NV.SRV.TOTL.ZS": "Services value added (% of GDP)",
        "NE.EXP.GNFS.ZS": "Exports of goods and services (% of GDP)",
        "NE.IMP.GNFS.ZS": "Imports of goods and services (% of GDP)",
    }, 
    #Mortality Rates and Life expectancy rates 
    "Mortality_life_expect": {
        "SP.DYN.IMRT.IN": "Mortality rate, infant (per 1,000 live births)",
        "SP.DYN.LE00.IN": "Life expectancy at birth, total (years)",
        "SP.DYN.IMRT.MA.IN": "Mortality rate, infant, male (per 1,000)",
        "SP.DYN.IMRT.FE.IN": "Mortality rate, infant, female (per 1,000)",
        "SP.DYN.LE00.MA.IN": "Life expectancy at birth, male (years)",
        "SP.DYN.LE00.FE.IN": "Life expectancy at birth, female (years)",
    }, 
    #Population Growth, Fertility Rates, and Age Dependacy Ratios
    "demographic_rates": {
        "SP.POP.GROW": "Population growth (annual %)",
        "SP.DYN.TFRT.IN": "Fertility rate, total (births per woman)",
        "SP.ADO.TFRT": "Adolescent fertility rate (births per 1,000 women ages 15-19)",
        "SP.POP.DPND": "Age dependency ratio (% of working-age population)",           
        "SP.POP.DPND.YG": "Age dependency ratio, young (% of working-age population)", 
        "SP.POP.DPND.OL": "Age dependency ratio, old (% of working-age population)", 
    }}

def get_dataframe(countries, years, groups):
    
    #parse countries 
    if isinstance(countries, str): 
        #split by comma or semicolon and strip whitespace 
        if "," in countries:
            country_list = [c.strip() for c in countries.split(',')]
        elif ":" in countries: 
            country_list = [c.strip() for c in countries.split(';')]
        else: 
            #Single Country 
            country_list = [countries.strip()]
     #already a list or single value 
    else: country_list = [countries] if not isinstance(countries, list) else countries

    #parse years 
    if isinstance(years, int): 
        #single year as an integer. example: 2000
        start_year = end_year = years 
    elif isinstance(years, str):
        years = years.strip()
        if "-" in years and not years.startswith("-"):
            #example: "2000-2015"
            start_year, end_year = map(int, years.split("-"))
        elif "to" in years.lower(): 
            #example: "2000 to 2015" 
            parts = years.lower().split("to")
            start_year = int(parts[0].strip())
            end_year = int(parts[1].strip())
        else: 
            #single year as a string. example: "2000" 
            start_year = end_year = int(years)
    else: 
        raise ValueError("Years must be an integer, string year, or year range")

    year_range = (str(start_year), str(end_year))
    
    # parse indicator groups
    if isinstance(groups, str):
        if "," in groups:
            group_list = [g.strip() for g in groups.split(",")]
        elif ";" in groups:
            group_list = [g.strip() for g in groups.split(";")]
        else:
            group_list = [groups.strip()]
    elif isinstance(groups, list):
        group_list = groups
    else:
        raise TypeError(
        "groups must be a string or list of strings "
        "(e.g. 'total_pop' or ['total_pop', 'rural_urban_pop'])"
        )

    for g in group_list:
        if not isinstance(g, str):
            raise TypeError(f"Invalid group type: {type(g)} — expected string")

    #collect all indicator codes from requested groups 
    indicators = {}
    for group in group_list:
        if group not in INDICATOR_GROUPS:
            available = '\n  - '.join(INDICATOR_GROUPS.keys())
            raise ValueError(f"Unknown indicator group '{group}'.\n\nAvailable groups:\n  - {available}")
        indicators.update(INDICATOR_GROUPS[group])

    valid_indicators = {}
    for code, name in indicators.items():
        try:
            test = wbdata.get_series(
                indicator=code,
                country=country_list,
                date=year_range
            )
            if test is not None and len(test) > 0:
                valid_indicators[code] = name
        except Exception:
            pass
    if not valid_indicators:
        raise ValueError("No indicators have data for the selected countries and years.")

    
    data_frame = wbdata.get_dataframe(valid_indicators, country=country_list, date=year_range)

    data_frame = data_frame.sort_index()

    return data_frame

# %% [markdown]
# # Example: Japan and Niger's Female Population Indexed by Age Group in the year 2000

# %%
df = get_dataframe("JPN, NER", "2000", "pop_female_age")
df.head()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-3281089980078572826' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3861708976189030533' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4387520020799357148' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6143789236062253969' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7854966470242199720' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3660760723624584937' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6901618868920389457' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8968508850165537196' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7712862647892646509' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7993802012266417944' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7784662407399993767' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6452781448299707239' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5810282976403274077' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-692935030216282592' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2648722157080418833' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3593456277151433623' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-210961145765880683' not in persistent cache.
#          Population ages 0-4, female  Population ages 5-9, female  \
# country
# Japan                      2876526.0                    2884718.0
# Niger                      1156941.0                     839232.0
#
#          Population ages 10-14, female  Population ages 15-19, female  \
# country
# Japan                        3129328.0                      3575570.0
# Niger                         681188.0                       577228.0
#
#          Population ages 20-24, female  Population ages 25-29, female  \
# country
# Japan                        4145342.0                      4889128.0
# Niger                         478574.0                       393501.0
#
#          Population ages 30-34, female  Population ages 35-39, female  \
# country
# Japan                        4227794.0                      3906124.0
# Niger                         331340.0                       280624.0
#
#          Population ages 40-44, female  Population ages 45-49, female  \
# country
# Japan                        3828357.0                      4384461.0
# Niger                         231528.0                       188413.0
#
#          Population ages 50-54, female  Population ages 55-59, female  \
# country
# Japan                        5377391.0                      4370492.0
# Niger                         158129.0                       135695.0
#
#          Population ages 60-64, female  Population ages 65-69, female  \
# country
# Japan                        4015631.0                      3747472.0
# Niger                          99901.0                        69942.0
#
#          Population ages 70-74, female  Population ages 75-79, female  \
# country
# Japan                        3237474.0                      2560664.0
# Niger                          44322.0                        23840.0
#
#          Population ages 80 and above, female
# country
# Japan                               3300344.0
# Niger                                 11862.0

# %% [markdown]
# # Example 2: Niger's Mortality and Life Expectancy over 10 years

# %%
df_two = get_dataframe("NER", "1965-1975", "Mortality_life_expect")
df_two.head()
# Out:
# WARNING:shelved_cache.persistent_cache:Key '-7323773047432143611' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2090856229945854693' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4171288078554456349' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1438111785165570049' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-555203784071134454' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4132997572477519607' not in persistent cache.
#       Mortality rate, infant (per 1,000 live births)  \
# date
# 1965                                             NaN
# 1966                                             NaN
# 1967                                             NaN
# 1968                                             NaN
# 1969                                           149.5
#
#       Life expectancy at birth, total (years)  \
# date
# 1965                                   36.404
# 1966                                   36.331
# 1967                                   36.243
# 1968                                   36.128
# 1969                                   36.003
#
#       Mortality rate, infant, male (per 1,000)  \
# date
# 1965                                       NaN
# 1966                                       NaN
# 1967                                       NaN
# 1968                                       NaN
# 1969                                     158.8
#
#       Mortality rate, infant, female (per 1,000)  \
# date
# 1965                                         NaN
# 1966                                         NaN
# 1967                                         NaN
# 1968                                         NaN
# 1969                                       139.6
#
#       Life expectancy at birth, male (years)  \
# date
# 1965                                  35.837
# 1966                                  35.784
# 1967                                  35.698
# 1968                                  35.585
# 1969                                  35.444
#
#       Life expectancy at birth, female (years)
# date
# 1965                                    36.870
# 1966                                    36.774
# 1967                                    36.684
# 1968                                    36.568
# 1969                                    36.462
